# %%
import os
import json
import pandas as pd

# %%
directory = 'results'

df_news_final = pd.DataFrame()

frames = list()

# Loop over files in the directory
for filename in os.scandir(directory):
    with open(f'./results/{filename.name}', encoding='utf8') as json_file:
        data = json.load(json_file)

    df_news = pd.DataFrame(data)

    # Convert date to datetime format
    df_news['date'] = pd.to_datetime(df_news['date'], format='%d/%m/%Y %H:%M')

    # Set date column as index
    df_news.set_index('date', inplace=True)

    # Order by date
    df_news.sort_index(inplace=True)

    frames.append(df_news)

for df in frames:
    df_news_final = df_news_final.append(df)

# %%
df_news_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2650 entries, 2018-09-24 12:21:00 to 2022-04-28 12:22:00
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   topic        2650 non-null   object
#  1   title        2650 non-null   object
#  2   search_date  2650 non-null   object
#  3   url          2650 non-null   object
#  4   tags         2650 non-null   object
# dtypes: object(5)
# memory usage: 124.2+ KB

# %%
df_news_final.sample(10)
# Out:
#                         topic  \
# date
# 2018-10-03 17:29:00  Política
# 2022-04-06 10:17:00  Negócios
# 2020-02-21 17:50:00   Mercado
# 2020-11-30 16:22:00  Negócios
# 2021-02-25 17:52:00  Negócios
# 2021-05-14 10:48:00   Mercado
# 2020-12-05 17:22:00  Negócios
# 2021-04-05 17:28:00   Mercado
# 2021-09-09 17:54:00   Mercado
# 2021-09-17 11:22:00   Mercado
#
#                                                                  title  \
# date
# 2018-10-03 17:29:00  XP elenca ações que se beneficiam com a ascens...
# 2022-04-06 10:17:00  Petrobras (PETR4), Vale (VALE3) e Hapvida (HAP...
# 2020-02-21 17:50:00  Dólar encerra em leve alta de 0,04%, cotado em...
# 2020-11-30 16:22:00  Petrobras (PETR4) arrecadará até US$ 35 bi com...
# 2021-02-25 17:52:00  Coinbase planeja IPO e pode valer mais do que ...
# 2021-05-14 10:48:00  Ibovespa sobe 1% na abertura, com alta de aére...
# 2020-12-05 17:22:00  BB (BBSA3) traça meta para chegar a 90% de ene...
# 2021-04-05 17:28:00  Ibovespa fecha em alta de 1,97% com Vale (VALE...
# 2021-09-09 17:54:00  Ibovespa salta 1,72% após carta de Bolsonaro; ...
# 2021-09-17 11:22:00  Ibovespa abre em queda com minério de ferro e ...
#
#                              search_date  \
# date
# 2018-10-03 17:29:00  2022-05-03 17:12:13
# 2022-04-06 10:17:00  2022-05-03 15:59:31
# 2020-02-21 17:50:00  2022-05-03 16:42:05
# 2020-11-30 16:22:00  2022-05-03 16:17:54
# 2021-02-25 17:52:00  2022-05-03 17:04:59
# 2021-05-14 10:48:00  2022-05-03 16:11:36
# 2020-12-05 17:22:00  2022-05-03 17:08:12
# 2021-04-05 17:28:00  2022-05-03 16:12:59
# 2021-09-09 17:54:00  2022-05-03 16:33:00
# 2021-09-17 11:22:00  2022-05-03 16:32:09
#
#                                                                    url  \
# date
# 2018-10-03 17:29:00  https://www.suno.com.br/noticias/xp-pesquisa-e...
# 2022-04-06 10:17:00  https://www.suno.com.br/noticias/petrobras-pet...
# 2020-02-21 17:50:00  https://www.suno.com.br/noticias/dolar-alta-00...
# 2020-11-30 16:22:00  https://www.suno.com.br/noticias/petrobras-pet...
# 2021-02-25 17:52:00  https://www.suno.com.br/noticias/coinbase-crip...
# 2021-05-14 10:48:00  https://www.suno.com.br/noticias/ibovespa-resu...
# 2020-12-05 17:22:00  https://www.suno.com.br/noticias/banco-do-bras...
# 2021-04-05 17:28:00  https://www.suno.com.br/noticias/ibovespa-fech...
# 2021-09-09 17:54:00  https://www.suno.com.br/noticias/ibovespa-salt...
# 2021-09-17 11:22:00  https://www.suno.com.br/noticias/ibovespa-abre...
#
#                                                                   tags
# date
# 2018-10-03 17:29:00       [Banco do Brasil (BBAS3), Petrobras (PETR4)]
# 2022-04-06 10:17:00                                [Petrobras (PETR4)]
# 2020-02-21 17:50:00                 [coronavírus, dólar, Vale (VALE3)]
# 2020-11-30 16:22:00                                [Petrobras (PETR4)]
# 2021-02-25 17:52:00  [Banco do Brasil (BBAS3), Bradesco (BBDC3/BBDC...
# 2021-05-14 10:48:00  [balanços trimestrais, Comissão Parlamentar de...
# 2020-12-05 17:22:00        [Banco do Brasil (BBAS3), Sustentabilidade]
# 2021-04-05 17:28:00  [Banco do Brasil (BBAS3), Especialistas, Ibove...
# 2021-09-09 17:54:00  [americanas S.A (AMER3), Bradespar (BRAP3/BRAP...
# 2021-09-17 11:22:00  [Bolsas mundiais, Especialistas, Gol Linhas Aé...

# %%
# Save df object
df_news_final.to_pickle('./news_df.pkl')
